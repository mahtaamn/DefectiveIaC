# %%
import requests
import json
import pandas as pd
from urllib.parse import parse_qs, urlparse
from dateutil import parser, relativedelta
import sys

headers = {
        #'Authorization': 'token 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',
        'Authorization': 'token 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',
        'Content-Type': 'application/json'
}
url = f"https://api.github.com/search/code?q=*+repo:Mirantis/cri-dockerd"
data = requests.get(url, headers=headers).json()
print(data)
print("1:",data["total_count"])
total_count = data["total_count"];
# Out:
# {'total_count': 4736, 'incomplete_results': False, 'items': [{'name': 'common.mk', 'path': 'packaging/common.mk', 'sha': '41f6bbf38ccac74bfd687b8c9245927b1e4f6c02', 'url': 'https://api.github.com/repositories/318491505/contents/packaging/common.mk?ref=d8accf791cbb9762a218f47507378a7c4cb63797', 'git_url': 'https://api.github.com/repositories/318491505/git/blobs/41f6bbf38ccac74bfd687b8c9245927b1e4f6c02', 'html_url': 'https://github.com/Mirantis/cri-dockerd/blob/d8accf791cbb9762a218f47507378a7c4cb63797/packaging/common.mk', 'repository': {'id': 318491505, 'node_id': 'MDEwOlJlcG9zaXRvcnkzMTg0OTE1MDU=', 'name': 'cri-dockerd', 'full_name': 'Mirantis/cri-dockerd', 'private': False, 'owner': {'login': 'Mirantis', 'id': 609319, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYwOTMxOQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/609319?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Mirantis', 'html_url': 'https://github.com/Mirantis', 'followers_url': 'https://api.github.com/use
# ...

# %%
headers = {
        'Authorization': 'token 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'
    }
response = requests.get('https://api.github.com/rate_limit', headers=headers)
print(response.text)
print(response)
return;
# Out:
# {"resources":{"core":{"limit":5000,"used":2,"remaining":4998,"reset":1670131709},"search":{"limit":30,"used":0,"remaining":30,"reset":1670128551},"graphql":{"limit":5000,"used":0,"remaining":5000,"reset":1670132091},"integration_manifest":{"limit":5000,"used":0,"remaining":5000,"reset":1670132091},"source_import":{"limit":100,"used":0,"remaining":100,"reset":1670128551},"code_scanning_upload":{"limit":1000,"used":0,"remaining":1000,"reset":1670132091},"actions_runner_registration":{"limit":10000,"used":0,"remaining":10000,"reset":1670132091},"scim":{"limit":15000,"used":0,"remaining":15000,"reset":1670132091},"dependency_snapshots":{"limit":100,"used":0,"remaining":100,"reset":1670128551}},"rate":{"limit":5000,"used":2,"remaining":4998,"reset":1670131709}}
# <Response [200]>
#   Input In [10]
#     return;
#     ^
# SyntaxError: 'return' outside function

# %%
from tempfile import NamedTemporaryFile
import shutil
import csv

filename = 'mirantis_repository.csv'
tempfile = NamedTemporaryFile(mode='w', delete=False)

fields = ['number', 'name', 'fulname', 'id','total_count','iac_count','iacPercent','isCriteria2Met']

with open(filename, 'r') as csvfile, tempfile:
    reader = csv.DictReader(csvfile, fieldnames=fields)
    writer = csv.DictWriter(tempfile, fieldnames=fields)
    for row in reader:
        print("The variable, name is of type:", type(row['iacPercent']))
        if float(row['iacPercent']) >= 0.11:
            print('updating row', row['iacPercent'])
            print('iac percent:',row['iacPercent'])
            #row['Name'], row['Course'], row['Year'] = stud_name, stud_course, stud_year
        #row = {'number': row['number'], 'name': row['name'], 'fulname': row['fulname']
               #, 'id': row['id'], 'total_count': row['total_count'], 'iac_count': row['iac_count']
               #, 'iacPercent': row['iacPercent'], 'isCriteria2Met': row['isCriteria2Met']}
        #writer.writerow(row)

#shutil.move(tempfile.name, filename)
# Out:
# The variable, name is of type: <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 10>()
#      13 for row in reader:
#      14     print("The variable, name is of type:", type(row['iacPercent']))
# ---> 15     if float(row['iacPercent']) >= 0.11:
#      16         print('updating row', row['iacPercent'])
#      17         print('iac percent:',row['iacPercent'])
#
# ValueError: could not convert string to float: 'iacPercent'
