# %%
# Authots' result

import pandas as pd

data = {'Recall': [0.66, 0.66, 0.60, 0.67 ],
        'Precision': [0.65, 0.68, 0.60, 0.67],
        'F_measure':[0.67, 0.67,0.60, 0.67],
        'AUC':[0.65, 0.71, 0.52, 0.64 ]}
 
df_article = pd.DataFrame(data, index=['Mirantis',
                               'Mozilla',
                               'OpenStack',
                               'Wikimedia'])

df_article
# Out:
#            Recall  Precision  F_measure   AUC
# Mirantis     0.66       0.65       0.67  0.65
# Mozilla      0.66       0.68       0.67  0.71
# OpenStack    0.60       0.60       0.60  0.52
# Wikimedia    0.67       0.67       0.67  0.64

# %%
# Our result

import pandas as pd

data = {'Recall': [0.63, 0.71, 0.50, 0.56],
        'Precision': [0.67, 0.70, 0.50, 0.63],
        'F_measure':[0.63, 0.70, 0.50, 0.63],
        'AUC':[0.62, 0.74, 0.41, 0.60]}
 
df_ours = pd.DataFrame(data, index=['Mirantis',
                               'Mozilla',
                               'OpenStack',
                               'Wikimedia'])
 
df_ours
# Out:
#            Recall  Precision  F_measure   AUC
# Mirantis     0.63       0.67       0.63  0.62
# Mozilla      0.71       0.70       0.70  0.74
# OpenStack    0.50       0.50       0.50  0.41
# Wikimedia    0.56       0.63       0.63  0.60
